# %%
import numpy as np
import matplotlib.pyplot as plt


#for i in range(500000):
chances = np.random.rand(25, 10000000)<0.0473
all_attempts = np.sum(chances*np.random.randint(low=4,high=9,size=(10000000, 25)).T, axis=0)
    #all_attempts.append(pearls)

plt.figure(figsize=(16,8))
plt.hist(np.array(pearls), bins = 15)
plt.show()

# %%
print('Шанс дропа как минимум 14 эндер перлов около: ' + str(sum(all_attempts>13)/len(all_attempts)*100) + '%')
# Out:
# Шанс дропа как минимум 14 эндер перлов около: 16.25396%
